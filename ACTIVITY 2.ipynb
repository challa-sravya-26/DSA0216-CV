# %%
# Install OpenCV (Colab usually has it, but this ensures it)
# !pip install opencv-python

import cv2
import numpy as np
from google.colab import files
from google.colab.patches import cv2_imshow

# ==============================
# STEP 1: Upload image from your device
# ==============================
uploaded = files.upload()

# Get the uploaded filename
image_path = next(iter(uploaded))

# ==============================
# STEP 2: Read the image
# ==============================
image = cv2.imread(image_path)

# ==============================
# STEP 3: Convert to grayscale
# ==============================
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# ==============================
# STEP 4: Reduce noise
# ==============================
blur = cv2.GaussianBlur(gray, (5, 5), 0)

# ==============================
# STEP 5: Edge detection
# ==============================
edges = cv2.Canny(blur, 50, 150)

# ==============================
# STEP 6: Contour tracing
# ==============================
contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# ==============================
# STEP 7: Draw contours
# ==============================
output = image.copy()
cv2.drawContours(output, contours, -1, (0, 255, 0), 2)

# ==============================
# STEP 8: Show results
# ==============================
print("Original Image")
cv2_imshow(image)

print("Edges")
cv2_imshow(edges)

print("Contour Tracing Output")
cv2_imshow(output)

print("Total contours detected:", len(contours))
# Out:
# ...
#      <input type="file" id="files-2aa1a0c5-907e-4c91-9da6-6e611c4a6de3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2aa1a0c5-907e-4c91-9da6-6e611c4a6de3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
