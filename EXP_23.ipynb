# %%
import cv2
import matplotlib.pyplot as plt

print("Experiment 23 - Histogram")

img = cv2.imread("sample 8.jpg",0)

if img is None:
    print("Upload sample 8.jpg")
else:
    plt.imshow(img, cmap='gray')
    plt.title("Input Image")
    plt.show()

    plt.hist(img.ravel(),256,[0,256])
    plt.title("Histogram")
    plt.show()
# Out:
# Experiment 23 - Histogram
# /tmp/ipython-input-743222914.py:15: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(img.ravel(),256,[0,256])
