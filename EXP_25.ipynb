# %%
import cv2
from google.colab.patches import cv2_imshow

print("Experiment 25 - Image Resizing")

img = cv2.imread("sample 8.png")

if img is None:
    print("Upload sample 8.png")
else:
    print("INPUT IMAGE:")
    cv2_imshow(img)

    resized = cv2.resize(img, (300,300))

    print("OUTPUT IMAGE:")
    cv2_imshow(resized)
# Out:
# Experiment 25 - Image Resizing
# INPUT IMAGE:
# <PIL.Image.Image image mode=RGB size=391x534>
# OUTPUT IMAGE:
# <PIL.Image.Image image mode=RGB size=300x300>
